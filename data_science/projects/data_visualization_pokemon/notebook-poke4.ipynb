# %% [markdown]
# # Getting the JSON data

# %%
import pandas as pd
import pokebase as pb

# %% [markdown]
# ## Getting pokemon names

# %%
# functions for getting api data
from tqdm import tqdm

def get_pokemon_metadata(number_count):
    """
    Returns a list of metadata for a list of Pokemon.

    Parameters:
    lista_names (list): A list of Pokemon names.

    Returns:
    list: A list of dictionaries containing the metadata for each Pokemon.
    The metadata includes the Pokemon's name, ID, height, weight, types, and abilities.
    """
    lista_names=list(range(1,number_count+1))
    metadata = [] 
    with tqdm(total=len(lista_names), desc='Catching the Pokemons...') as pbar:
        for name in lista_names:
            pokemon = pb.pokemon(name)
            metadata.append({
                'name': pokemon.name,
                'id': pokemon.id,
                'hp': pokemon.stats[0].base_stat,
                'attack': pokemon.stats[1].base_stat,
                'defense': pokemon.stats[2].base_stat,
                'special_attack': pokemon.stats[3].base_stat,
                'special_defense': pokemon.stats[4].base_stat,
                'speed': pokemon.stats[5].base_stat,
                'height': pokemon.height,
                'weight': pokemon.weight,
                'types': [t.type.name for t in pokemon.types],
                'abilities': [a.ability.name for a in pokemon.abilities]})
            pbar.update(1)
    return metadata

def get_location_metadata(lista_names):
    """
    Returns a list of metadata for a list of locations.

    Parameters:
    lista_names (list): A list of location names.

    Returns:
    list: A list of dictionaries containing the metadata for each location.
    The metadata includes the location's name, ID, areas, region, and generation.
    """
    metadata = []
    for name in lista_names:
        location = pb.location(name)
        metadata.append({
            'name': location.name,
            'id': location.id,
            'areas': [a.name for a in location.areas],
            'region': location.region.name,
            'generation': location.game_indices[0].generation.name
        })
    return metadata


def get_move_metadata(lista_names):
    metadata = []
    for name in lista_names:
        try:
            move = pb.move(name)
            print(f"Getting {move.name} metadata")
            metadata.append({
                'name': move.name,
                'id': move.id,
                'accuracy': move.accuracy,
                'pp': move.pp,
                'power': move.power,
                'priority': move.priority,
                'type': move.type.name,
                'generation': move.generation.name,
                'short_descripton': move.effect_entries[0].short_effect,
                'damage_class': move.damage_class.name
            })
        except Exception as e:
            print("Error {} id: {}".format(e, name))
    return metadata

# %%
pokemon_data = get_pokemon_metadata(10)
print(pokemon_data)
# Out:
# Catching the Pokemons...: 100%|██████████| 9/9 [01:10<00:00,  7.80s/it]
# [{'name': 'bulbasaur', 'id': 1, 'hp': 45, 'attack': 49, 'defense': 49, 'special_attack': 65, 'special_defense': 65, 'speed': 45, 'height': 7, 'weight': 69, 'types': ['grass', 'poison'], 'abilities': ['overgrow', 'chlorophyll']}, {'name': 'ivysaur', 'id': 2, 'hp': 60, 'attack': 62, 'defense': 63, 'special_attack': 80, 'special_defense': 80, 'speed': 60, 'height': 10, 'weight': 130, 'types': ['grass', 'poison'], 'abilities': ['overgrow', 'chlorophyll']}, {'name': 'venusaur', 'id': 3, 'hp': 80, 'attack': 82, 'defense': 83, 'special_attack': 100, 'special_defense': 100, 'speed': 80, 'height': 20, 'weight': 1000, 'types': ['grass', 'poison'], 'abilities': ['overgrow', 'chlorophyll']}, {'name': 'charmander', 'id': 4, 'hp': 39, 'attack': 52, 'defense': 43, 'special_attack': 60, 'special_defense': 50, 'speed': 65, 'height': 6, 'weight': 85, 'types': ['fire'], 'abilities': ['blaze', 'solar-power']}, {'name': 'charmeleon', 'id': 5, 'hp': 58, 'attack': 64, 'defense': 58, 'special_attack': 80, 'special_defense': 65, 'speed': 80, 'height': 11, 'weight': 190, 'types': ['fire'], 'abilities': ['blaze', 'solar-power']}, {'name': 'charizard', 'id': 6, 'hp': 78, 'attack': 84, 'defense': 78, 'special_attack': 109, 'special_defense': 85, 'speed': 100, 'height': 17, 'weight': 905, 'types': ['fire', 'flying'], 'abilities': ['blaze', 'solar-power']}, {'name': 'squirtle', 'id': 7, 'hp': 44, 'attack': 48, 'defense': 65, 'special_attack': 50, 'special_defense': 64, 'speed': 43, 'height': 5, 'weight': 90, 'types': ['water'], 'abilities': ['torrent', 'rain-dish']}, {'name': 'wartortle', 'id': 8, 'hp': 59, 'attack': 63, 'defense': 80, 'special_attack': 65, 'special_defense': 80, 'speed': 58, 'height': 10, 'weight': 225, 'types': ['water'], 'abilities': ['torrent', 'rain-dish']}, {'name': 'blastoise', 'id': 9, 'hp': 79, 'attack': 83, 'defense': 100, 'special_attack': 85, 'special_defense': 105, 'speed': 78, 'height': 16, 'weight': 855, 'types': ['water'], 'abilities': ['torrent', 'rain-dish']}]

# %%
poke_df = pd.json_normalize(pokemon_data)
print(poke_df)
# Out:
#          name  id  hp  attack  defense  special_attack  special_defense  \
# 0   bulbasaur   1  45      49       49              65               65
# 1     ivysaur   2  60      62       63              80               80
# 2    venusaur   3  80      82       83             100              100
# 3  charmander   4  39      52       43              60               50
# 4  charmeleon   5  58      64       58              80               65
# 5   charizard   6  78      84       78             109               85
# 6    squirtle   7  44      48       65              50               64
# 7   wartortle   8  59      63       80              65               80
# 8   blastoise   9  79      83      100              85              105
#
#    speed  height  weight            types                abilities
# 0     45       7      69  [grass, poison]  [overgrow, chlorophyll]
# 1     60      10     130  [grass, poison]  [overgrow, chlorophyll]
# 2     80      20    1000  [grass, poison]  [overgrow, chlorophyll]
# 3     65       6      85           [fire]     [blaze, solar-power]
# 4     80      11     190           [fire]     [blaze, solar-power]
# 5    100      17     905   [fire, flying]     [blaze, solar-power]
# 6     43       5      90          [water]     [torrent, rain-dish]
# 7     58      10     225          [water]     [torrent, rain-dish]
# 8     78      16     855          [water]     [torrent, rain-dish]

# %%
lista_num = list(range(1,999)) 
moves_data = get_move_metadata(lista_num)
moves_data = pd.DataFrame(moves_data)
moves_data.head()
# Out:
# Getting pound metadata
# Getting karate-chop metadata
# Getting double-slap metadata
# Getting comet-punch metadata
# Getting mega-punch metadata
# Getting pay-day metadata
# Getting fire-punch metadata
# Getting ice-punch metadata
# Getting thunder-punch metadata
# Getting scratch metadata
# Getting vice-grip metadata
# Getting guillotine metadata
# Getting razor-wind metadata
# Getting swords-dance metadata
# Getting cut metadata
# Getting gust metadata
# Getting wing-attack metadata
# Getting whirlwind metadata
# Getting fly metadata
# Getting bind metadata
# Getting slam metadata
# Getting vine-whip metadata
# Getting stomp metadata
# Getting double-kick metadata
# Getting mega-kick metadata
# Getting jump-kick metadata
# Getting rolling-kick metadata
# Getting sand-attack metadata
# Getting headbutt metadata
# Getting horn-attack metadata
# Getting fury-attack metadata
# Getting horn-drill metadata
# Getting tackle metadata
# Getting body-slam metadata
# Getting wrap metadata
# Getting take-down metadata
# Getting thrash metadata
# Getting double-edge metadata
# Getting tail-whip metadata
# Getting poison-sting metadata
# Getting twineedle metadata
# Getting pin-missile metadata
# Getting leer metadata
# Getting bite metadata
# Getting growl metadata
# Getting roar metadata
# Getting sing metadata
# Getting supersonic metadata
# Getting sonic-boom metadata
# Getting disable metadata
# Getting acid metadata
# Getting ember metadata
# Getting flamethrower metadata
# Getting mist metadata
# Getting water-gun metadata
# Getting hydro-pump metadata
# Getting surf metadata
# Getting ice-beam metadata
# Getting blizzard metadata
# Getting psybeam metadata
# Getting bubble-beam metadata
# Getting aurora-beam metadata
# Getting hyper-beam metadata
# Getting peck metadata
# Getting drill-peck metadata
# Getting submission metadata
# Getting low-kick metadata
# Getting counter metadata
# Getting seismic-toss metadata
# Getting strength metadata
# Getting absorb metadata
# Getting mega-drain metadata
# Getting leech-seed metadata
# Getting growth metadata
# Getting razor-leaf metadata
# Getting solar-beam metadata
# Getting poison-powder metadata
# Getting stun-spore metadata
# Getting sleep-powder metadata
# Getting petal-dance metadata
# Getting string-shot metadata
# Getting dragon-rage metadata
# Getting fire-spin metadata
# Getting thunder-shock metadata
# Getting thunderbolt metadata
# Getting thunder-wave metadata
# Getting thunder metadata
# Getting rock-throw metadata
# Getting earthquake metadata
# Getting fissure metadata
# Getting dig metadata
# Getting toxic metadata
# Getting confusion metadata
# Getting psychic metadata
# Getting hypnosis metadata
# Getting meditate metadata
# Getting agility metadata
# Getting quick-attack metadata
# Getting rage metadata
# Getting teleport metadata
# Getting night-shade metadata
# Getting mimic metadata
# Getting screech metadata
# Getting double-team metadata
# Getting recover metadata
# Getting harden metadata
# Getting minimize metadata
# Getting smokescreen metadata
# Getting confuse-ray metadata
# Getting withdraw metadata
# Getting defense-curl metadata
# Getting barrier metadata
# Getting light-screen metadata
# Getting haze metadata
# Getting reflect metadata
# Getting focus-energy metadata
# Getting bide metadata
# Getting metronome metadata
# Getting mirror-move metadata
# Getting self-destruct metadata
# Getting egg-bomb metadata
# Getting lick metadata
# Getting smog metadata
# Getting sludge metadata
# Getting bone-club metadata
# Getting fire-blast metadata
# Getting waterfall metadata
# Getting clamp metadata
# Getting swift metadata
# Getting skull-bash metadata
# Getting spike-cannon metadata
# Getting constrict metadata
# Getting amnesia metadata
# Getting kinesis metadata
# Getting soft-boiled metadata
# Getting high-jump-kick metadata
# Getting glare metadata
# Getting dream-eater metadata
# Getting poison-gas metadata
# Getting barrage metadata
# Getting leech-life metadata
# Getting lovely-kiss metadata
# Getting sky-attack metadata
# Getting transform metadata
# Getting bubble metadata
# Getting dizzy-punch metadata
# Getting spore metadata
# Getting flash metadata
# Getting psywave metadata
# Getting splash metadata
# Getting acid-armor metadata
# Getting crabhammer metadata
# Getting explosion metadata
# Getting fury-swipes metadata
# Getting bonemerang metadata
# Getting rest metadata
# Getting rock-slide metadata
# Getting hyper-fang metadata
# Getting sharpen metadata
# Getting conversion metadata
# Getting tri-attack metadata
# Getting super-fang metadata
# Getting slash metadata
# Getting substitute metadata
# Getting struggle metadata
# Getting sketch metadata
# Getting triple-kick metadata
# Getting thief metadata
# Getting spider-web metadata
# Getting mind-reader metadata
# Getting nightmare metadata
# Getting flame-wheel metadata
# Getting snore metadata
# Getting curse metadata
# Getting flail metadata
# Getting conversion-2 metadata
# Getting aeroblast metadata
# Getting cotton-spore metadata
# Getting reversal metadata
# Getting spite metadata
# Getting powder-snow metadata
# Getting protect metadata
# Getting mach-punch metadata
# Getting scary-face metadata
# Getting feint-attack metadata
# Getting sweet-kiss metadata
# Getting belly-drum metadata
# Getting sludge-bomb metadata
# Getting mud-slap metadata
# Getting octazooka metadata
# Getting spikes metadata
# Getting zap-cannon metadata
# Getting foresight metadata
# Getting destiny-bond metadata
# Getting perish-song metadata
# Getting icy-wind metadata
# Getting detect metadata
# Getting bone-rush metadata
# Getting lock-on metadata
# Getting outrage metadata
# Getting sandstorm metadata
# Getting giga-drain metadata
# Getting endure metadata
# Getting charm metadata
# Getting rollout metadata
# Getting false-swipe metadata
# Getting swagger metadata
# Getting milk-drink metadata
# Getting spark metadata
# Getting fury-cutter metadata
# Getting steel-wing metadata
# Getting mean-look metadata
# Getting attract metadata
# Getting sleep-talk metadata
# Getting heal-bell metadata
# Getting return metadata
# Getting present metadata
# Getting frustration metadata
# Getting safeguard metadata
# Getting pain-split metadata
# Getting sacred-fire metadata
# Getting magnitude metadata
# Getting dynamic-punch metadata
# Getting megahorn metadata
# Getting dragon-breath metadata
# Getting baton-pass metadata
# Getting encore metadata
# Getting pursuit metadata
# Getting rapid-spin metadata
# Getting sweet-scent metadata
# Getting iron-tail metadata
# Getting metal-claw metadata
# Getting vital-throw metadata
# Getting morning-sun metadata
# Getting synthesis metadata
# Getting moonlight metadata
# Getting hidden-power metadata
# Getting cross-chop metadata
# Getting twister metadata
# Getting rain-dance metadata
# Getting sunny-day metadata
# Getting crunch metadata
# Getting mirror-coat metadata
# Getting psych-up metadata
# Getting extreme-speed metadata
# Getting ancient-power metadata
# Getting shadow-ball metadata
# Getting future-sight metadata
# Getting rock-smash metadata
# Getting whirlpool metadata
# Getting beat-up metadata
# Getting fake-out metadata
# Getting uproar metadata
# Getting stockpile metadata
# Getting spit-up metadata
# Getting swallow metadata
# Getting heat-wave metadata
# Getting hail metadata
# Getting torment metadata
# Getting flatter metadata
# Getting will-o-wisp metadata
# Getting memento metadata
# Getting facade metadata
# Getting focus-punch metadata
# Getting smelling-salts metadata
# Getting follow-me metadata
# Getting nature-power metadata
# Getting charge metadata
# Getting taunt metadata
# Getting helping-hand metadata
# Getting trick metadata
# Getting role-play metadata
# Getting wish metadata
# Getting assist metadata
# Getting ingrain metadata
# Getting superpower metadata
# Getting magic-coat metadata
# Getting recycle metadata
# Getting revenge metadata
# Getting brick-break metadata
# Getting yawn metadata
# Getting knock-off metadata
# Getting endeavor metadata
# Getting eruption metadata
# Getting skill-swap metadata
# Getting imprison metadata
# Getting refresh metadata
# Getting grudge metadata
# Getting snatch metadata
# Getting secret-power metadata
# Getting dive metadata
# Getting arm-thrust metadata
# Getting camouflage metadata
# Getting tail-glow metadata
# Getting luster-purge metadata
# Getting mist-ball metadata
# Getting feather-dance metadata
# Getting teeter-dance metadata
# Getting blaze-kick metadata
# Getting mud-sport metadata
# Getting ice-ball metadata
# Getting needle-arm metadata
# Getting slack-off metadata
# Getting hyper-voice metadata
# Getting poison-fang metadata
# Getting crush-claw metadata
# Getting blast-burn metadata
# Getting hydro-cannon metadata
# Getting meteor-mash metadata
# Getting astonish metadata
# Getting weather-ball metadata
# Getting aromatherapy metadata
# Getting fake-tears metadata
# Getting air-cutter metadata
# Getting overheat metadata
# Getting odor-sleuth metadata
# Getting rock-tomb metadata
# Getting silver-wind metadata
# Getting metal-sound metadata
# Getting grass-whistle metadata
# Getting tickle metadata
# Getting cosmic-power metadata
# Getting water-spout metadata
# Getting signal-beam metadata
# Getting shadow-punch metadata
# Getting extrasensory metadata
# Getting sky-uppercut metadata
# Getting sand-tomb metadata
# Getting sheer-cold metadata
# Getting muddy-water metadata
# Getting bullet-seed metadata
# Getting aerial-ace metadata
# Getting icicle-spear metadata
# Getting iron-defense metadata
# Getting block metadata
# Getting howl metadata
# Getting dragon-claw metadata
# Getting frenzy-plant metadata
# Getting bulk-up metadata
# Getting bounce metadata
# Getting mud-shot metadata
# Getting poison-tail metadata
# Getting covet metadata
# Getting volt-tackle metadata
# Getting magical-leaf metadata
# Getting water-sport metadata
# Getting calm-mind metadata
# Getting leaf-blade metadata
# Getting dragon-dance metadata
# Getting rock-blast metadata
# Getting shock-wave metadata
# Getting water-pulse metadata
# Getting doom-desire metadata
# Getting psycho-boost metadata
# Getting roost metadata
# Getting gravity metadata
# Getting miracle-eye metadata
# Getting wake-up-slap metadata
# Getting hammer-arm metadata
# Getting gyro-ball metadata
# Getting healing-wish metadata
# Getting brine metadata
# Getting natural-gift metadata
# Getting feint metadata
# Getting pluck metadata
# Getting tailwind metadata
# Getting acupressure metadata
# Getting metal-burst metadata
# Getting u-turn metadata
# Getting close-combat metadata
# Getting payback metadata
# Getting assurance metadata
# Getting embargo metadata
# Getting fling metadata
# Getting psycho-shift metadata
# Getting trump-card metadata
# Getting heal-block metadata
# Getting wring-out metadata
# Getting power-trick metadata
# Getting gastro-acid metadata
# Getting lucky-chant metadata
# Getting me-first metadata
# Getting copycat metadata
# Getting power-swap metadata
# Getting guard-swap metadata
# Getting punishment metadata
# Getting last-resort metadata
# Getting worry-seed metadata
# Getting sucker-punch metadata
# Getting toxic-spikes metadata
# Getting heart-swap metadata
# Getting aqua-ring metadata
# Getting magnet-rise metadata
# Getting flare-blitz metadata
# Getting force-palm metadata
# Getting aura-sphere metadata
# Getting rock-polish metadata
# Getting poison-jab metadata
# Getting dark-pulse metadata
# Getting night-slash metadata
# Getting aqua-tail metadata
# Getting seed-bomb metadata
# Getting air-slash metadata
# Getting x-scissor metadata
# Getting bug-buzz metadata
# Getting dragon-pulse metadata
# Getting dragon-rush metadata
# Getting power-gem metadata
# Getting drain-punch metadata
# Getting vacuum-wave metadata
# Getting focus-blast metadata
# Getting energy-ball metadata
# Getting brave-bird metadata
# Getting earth-power metadata
# Getting switcheroo metadata
# Getting giga-impact metadata
# Getting nasty-plot metadata
# Getting bullet-punch metadata
# Getting avalanche metadata
# Getting ice-shard metadata
# Getting shadow-claw metadata
# Getting thunder-fang metadata
# Getting ice-fang metadata
# Getting fire-fang metadata
# Getting shadow-sneak metadata
# Getting mud-bomb metadata
# Getting psycho-cut metadata
# Getting zen-headbutt metadata
# Getting mirror-shot metadata
# Getting flash-cannon metadata
# Getting rock-climb metadata
# Getting defog metadata
# Getting trick-room metadata
# Getting draco-meteor metadata
# Getting discharge metadata
# Getting lava-plume metadata
# Getting leaf-storm metadata
# Getting power-whip metadata
# Getting rock-wrecker metadata
# Getting cross-poison metadata
# Getting gunk-shot metadata
# Getting iron-head metadata
# Getting magnet-bomb metadata
# Getting stone-edge metadata
# Getting captivate metadata
# Getting stealth-rock metadata
# Getting grass-knot metadata
# Getting chatter metadata
# Getting judgment metadata
# Getting bug-bite metadata
# Getting charge-beam metadata
# Getting wood-hammer metadata
# Getting aqua-jet metadata
# Getting attack-order metadata
# Getting defend-order metadata
# Getting heal-order metadata
# Getting head-smash metadata
# Getting double-hit metadata
# Getting roar-of-time metadata
# Getting spacial-rend metadata
# Getting lunar-dance metadata
# Getting crush-grip metadata
# Getting magma-storm metadata
# Getting dark-void metadata
# Getting seed-flare metadata
# Getting ominous-wind metadata
# Getting shadow-force metadata
# Getting hone-claws metadata
# Getting wide-guard metadata
# Getting guard-split metadata
# Getting power-split metadata
# Getting wonder-room metadata
# Getting psyshock metadata
# Getting venoshock metadata
# Getting autotomize metadata
# Getting rage-powder metadata
# Getting telekinesis metadata
# Getting magic-room metadata
# Getting smack-down metadata
# Getting storm-throw metadata
# Getting flame-burst metadata
# Getting sludge-wave metadata
# Getting quiver-dance metadata
# Getting heavy-slam metadata
# Getting synchronoise metadata
# Getting electro-ball metadata
# Getting soak metadata
# Getting flame-charge metadata
# Getting coil metadata
# Getting low-sweep metadata
# Getting acid-spray metadata
# Getting foul-play metadata
# Getting simple-beam metadata
# Getting entrainment metadata
# Getting after-you metadata
# Getting round metadata
# Getting echoed-voice metadata
# Getting chip-away metadata
# Getting clear-smog metadata
# Getting stored-power metadata
# Getting quick-guard metadata
# Getting ally-switch metadata
# Getting scald metadata
# Getting shell-smash metadata
# Getting heal-pulse metadata
# Getting hex metadata
# Getting sky-drop metadata
# Getting shift-gear metadata
# Getting circle-throw metadata
# Getting incinerate metadata
# Getting quash metadata
# Getting acrobatics metadata
# Getting reflect-type metadata
# Getting retaliate metadata
# Getting final-gambit metadata
# Getting bestow metadata
# Getting inferno metadata
# Getting water-pledge metadata
# Getting fire-pledge metadata
# Getting grass-pledge metadata
# Getting volt-switch metadata
# Getting struggle-bug metadata
# Getting bulldoze metadata
# Getting frost-breath metadata
# Getting dragon-tail metadata
# Getting work-up metadata
# Getting electroweb metadata
# Getting wild-charge metadata
# Getting drill-run metadata
# Getting dual-chop metadata
# Getting heart-stamp metadata
# Getting horn-leech metadata
# Getting sacred-sword metadata
# Getting razor-shell metadata
# Getting heat-crash metadata
# Getting leaf-tornado metadata
# Getting steamroller metadata
# Getting cotton-guard metadata
# Getting night-daze metadata
# Getting psystrike metadata
# Getting tail-slap metadata
# Getting hurricane metadata
# Getting head-charge metadata
# Getting gear-grind metadata
# Getting searing-shot metadata
# Getting techno-blast metadata
# Getting relic-song metadata
# Getting secret-sword metadata
# Getting glaciate metadata
# Getting bolt-strike metadata
# Getting blue-flare metadata
# Getting fiery-dance metadata
# Getting freeze-shock metadata
# Getting ice-burn metadata
# Getting snarl metadata
# Getting icicle-crash metadata
# Getting v-create metadata
# Getting fusion-flare metadata
# Getting fusion-bolt metadata
# Getting flying-press metadata
# Getting mat-block metadata
# Getting belch metadata
# Getting rototiller metadata
# Getting sticky-web metadata
# Getting fell-stinger metadata
# Getting phantom-force metadata
# Getting trick-or-treat metadata
# Getting noble-roar metadata
# Getting ion-deluge metadata
# Getting parabolic-charge metadata
# Getting forests-curse metadata
# Getting petal-blizzard metadata
# Getting freeze-dry metadata
# Getting disarming-voice metadata
# Getting parting-shot metadata
# Getting topsy-turvy metadata
# Getting draining-kiss metadata
# Getting crafty-shield metadata
# Getting flower-shield metadata
# Getting grassy-terrain metadata
# Getting misty-terrain metadata
# Getting electrify metadata
# Getting play-rough metadata
# Getting fairy-wind metadata
# Getting moonblast metadata
# Getting boomburst metadata
# Getting fairy-lock metadata
# Getting kings-shield metadata
# Getting play-nice metadata
# Getting confide metadata
# Getting diamond-storm metadata
# Getting steam-eruption metadata
# Getting hyperspace-hole metadata
# Getting water-shuriken metadata
# Getting mystical-fire metadata
# Getting spiky-shield metadata
# Getting aromatic-mist metadata
# Getting eerie-impulse metadata
# Getting venom-drench metadata
# Getting powder metadata
# Getting geomancy metadata
# Getting magnetic-flux metadata
# Getting happy-hour metadata
# Getting electric-terrain metadata
# Getting dazzling-gleam metadata
# Getting celebrate metadata
# Getting hold-hands metadata
# Getting baby-doll-eyes metadata
# Getting nuzzle metadata
# Getting hold-back metadata
# Getting infestation metadata
# Getting power-up-punch metadata
# Getting oblivion-wing metadata
# Getting thousand-arrows metadata
# Getting thousand-waves metadata
# Getting lands-wrath metadata
# Getting light-of-ruin metadata
# Getting origin-pulse metadata
# Getting precipice-blades metadata
# Getting dragon-ascent metadata
# Getting hyperspace-fury metadata
# Getting breakneck-blitz--physical metadata
# Getting breakneck-blitz--special metadata
# Getting all-out-pummeling--physical metadata
# Getting all-out-pummeling--special metadata
# Getting supersonic-skystrike--physical metadata
# Getting supersonic-skystrike--special metadata
# Getting acid-downpour--physical metadata
# Getting acid-downpour--special metadata
# Getting tectonic-rage--physical metadata
# Getting tectonic-rage--special metadata
# Getting continental-crush--physical metadata
# Getting continental-crush--special metadata
# Getting savage-spin-out--physical metadata
# Getting savage-spin-out--special metadata
# Getting never-ending-nightmare--physical metadata
# Getting never-ending-nightmare--special metadata
# Getting corkscrew-crash--physical metadata
# Getting corkscrew-crash--special metadata
# Getting inferno-overdrive--physical metadata
# Getting inferno-overdrive--special metadata
# Getting hydro-vortex--physical metadata
# Getting hydro-vortex--special metadata
# Getting bloom-doom--physical metadata
# Getting bloom-doom--special metadata
# Getting gigavolt-havoc--physical metadata
# Getting gigavolt-havoc--special metadata
# Getting shattered-psyche--physical metadata
# Getting shattered-psyche--special metadata
# Getting subzero-slammer--physical metadata
# Getting subzero-slammer--special metadata
# Getting devastating-drake--physical metadata
# Getting devastating-drake--special metadata
# Getting black-hole-eclipse--physical metadata
# Getting black-hole-eclipse--special metadata
# Getting twinkle-tackle--physical metadata
# Getting twinkle-tackle--special metadata
# Getting catastropika metadata
# Getting shore-up metadata
# Getting first-impression metadata
# Getting baneful-bunker metadata
# Getting spirit-shackle metadata
# Getting darkest-lariat metadata
# Getting sparkling-aria metadata
# Getting ice-hammer metadata
# Getting floral-healing metadata
# Getting high-horsepower metadata
# Getting strength-sap metadata
# Getting solar-blade metadata
# Getting leafage metadata
# Getting spotlight metadata
# Getting toxic-thread metadata
# Getting laser-focus metadata
# Getting gear-up metadata
# Getting throat-chop metadata
# Getting pollen-puff metadata
# Getting anchor-shot metadata
# Getting psychic-terrain metadata
# Getting lunge metadata
# Getting fire-lash metadata
# Getting power-trip metadata
# Getting burn-up metadata
# Getting speed-swap metadata
# Getting smart-strike metadata
# Getting purify metadata
# Getting revelation-dance metadata
# Getting core-enforcer metadata
# Getting trop-kick metadata
# Getting instruct metadata
# Getting beak-blast metadata
# Getting clanging-scales metadata
# Getting dragon-hammer metadata
# Getting brutal-swing metadata
# Getting aurora-veil metadata
# Getting sinister-arrow-raid metadata
# Getting malicious-moonsault metadata
# Getting oceanic-operetta metadata
# Getting guardian-of-alola metadata
# Getting soul-stealing-7-star-strike metadata
# Getting stoked-sparksurfer metadata
# Getting pulverizing-pancake metadata
# Getting extreme-evoboost metadata
# Getting genesis-supernova metadata
# Getting shell-trap metadata
# Getting fleur-cannon metadata
# Getting psychic-fangs metadata
# Getting stomping-tantrum metadata
# Getting shadow-bone metadata
# Getting accelerock metadata
# Getting liquidation metadata
# Getting prismatic-laser metadata
# Getting spectral-thief metadata
# Getting sunsteel-strike metadata
# Getting moongeist-beam metadata
# Getting tearful-look metadata
# Getting zing-zap metadata
# Getting natures-madness metadata
# Getting multi-attack metadata
# Getting 10-000-000-volt-thunderbolt metadata
# Getting mind-blown metadata
# Getting plasma-fists metadata
# Getting photon-geyser metadata
# Getting light-that-burns-the-sky metadata
# Getting searing-sunraze-smash metadata
# Getting menacing-moonraze-maelstrom metadata
# Getting lets-snuggle-forever metadata
# Getting splintered-stormshards metadata
# Getting clangorous-soulblaze metadata
# Getting zippy-zap metadata
# Getting splishy-splash metadata
# Getting floaty-fall metadata
# Getting pika-papow metadata
# Getting bouncy-bubble metadata
# Getting buzzy-buzz metadata
# Getting sizzly-slide metadata
# Getting glitzy-glow metadata
# Getting baddy-bad metadata
# Getting sappy-seed metadata
# Getting freezy-frost metadata
# Getting sparkly-swirl metadata
# Getting veevee-volley metadata
# Getting double-iron-bash metadata
# Getting max-guard metadata
# Getting dynamax-cannon metadata
# Getting snipe-shot metadata
# Getting jaw-lock metadata
# Getting stuff-cheeks metadata
# Getting no-retreat metadata
# Getting tar-shot metadata
# Error list index out of range id: 749
# Getting magic-powder metadata
# Error list index out of range id: 750
# Getting dragon-darts metadata
# Error list index out of range id: 751
# Getting teatime metadata
# Error list index out of range id: 752
# Getting octolock metadata
# Error list index out of range id: 753
# Getting bolt-beak metadata
# Error list index out of range id: 754
# Getting fishious-rend metadata
# Error list index out of range id: 755
# Getting court-change metadata
# Error list index out of range id: 756
# Getting max-flare metadata
# Getting max-flutterby metadata
# Getting max-lightning metadata
# Getting max-strike metadata
# Getting max-knuckle metadata
# Getting max-phantasm metadata
# Getting max-hailstorm metadata
# Getting max-ooze metadata
# Getting max-geyser metadata
# Getting max-airstream metadata
# Getting max-starfall metadata
# Getting max-wyrmwind metadata
# Getting max-mindstorm metadata
# Getting max-rockfall metadata
# Getting max-quake metadata
# Getting max-darkness metadata
# Getting max-overgrowth metadata
# Getting max-steelspike metadata
# Getting clangorous-soul metadata
# Error list index out of range id: 775
# Getting body-press metadata
# Error list index out of range id: 776
# Getting decorate metadata
# Error list index out of range id: 777
# Getting drum-beating metadata
# Getting snap-trap metadata
# Getting pyro-ball metadata
# Getting behemoth-blade metadata
# Error list index out of range id: 781
# Getting behemoth-bash metadata
# Error list index out of range id: 782
# Getting aura-wheel metadata
# Error list index out of range id: 783
# Getting breaking-swipe metadata
# Getting branch-poke metadata
# Getting overdrive metadata
# Error list index out of range id: 786
# Getting apple-acid metadata
# Error list index out of range id: 787
# Getting grav-apple metadata
# Getting spirit-break metadata
# Getting strange-steam metadata
# Getting life-dew metadata
# Error list index out of range id: 791
# Getting obstruct metadata
# Error list index out of range id: 792
# Getting false-surrender metadata
# Getting meteor-assault metadata
# Getting eternabeam metadata
# Getting steel-beam metadata
# Getting expanding-force metadata
# Getting steel-roller metadata
# Getting scale-shot metadata
# Getting meteor-beam metadata
# Getting shell-side-arm metadata
# Getting misty-explosion metadata
# Getting grassy-glide metadata
# Getting rising-voltage metadata
# Getting terrain-pulse metadata
# Getting skitter-smack metadata
# Getting burning-jealousy metadata
# Getting lash-out metadata
# Getting poltergeist metadata
# Getting corrosive-gas metadata
# Getting coaching metadata
# Getting flip-turn metadata
# Getting triple-axel metadata
# Getting dual-wingbeat metadata
# Getting scorching-sands metadata
# Getting jungle-healing metadata
# Getting wicked-blow metadata
# Getting surging-strikes metadata
# Getting thunder-cage metadata
# Getting dragon-energy metadata
# Getting freezing-glare metadata
# Getting fiery-wrath metadata
# Getting thunderous-kick metadata
# Getting glacial-lance metadata
# Getting astral-barrage metadata
# Getting eerie-spell metadata
# Getting dire-claw metadata
# Error list index out of range id: 827
# Getting psyshield-bash metadata
# Error list index out of range id: 828
# Getting power-shift metadata
# Error list index out of range id: 829
# Getting stone-axe metadata
# Error list index out of range id: 830
# Getting springtide-storm metadata
# Error list index out of range id: 831
# Getting mystical-power metadata
# Error list index out of range id: 832
# Getting raging-fury metadata
# Error list index out of range id: 833
# Getting wave-crash metadata
# Error list index out of range id: 834
# Getting chloroblast metadata
# Error list index out of range id: 835
# Getting mountain-gale metadata
# Error list index out of range id: 836
# Getting victory-dance metadata
# Error list index out of range id: 837
# Getting headlong-rush metadata
# Error list index out of range id: 838
# Getting barb-barrage metadata
# Error list index out of range id: 839
# Getting esper-wing metadata
# Error list index out of range id: 840
# Getting bitter-malice metadata
# Error list index out of range id: 841
# Getting shelter metadata
# Error list index out of range id: 842
# Getting triple-arrows metadata
# Error list index out of range id: 843
# Getting infernal-parade metadata
# Error list index out of range id: 844
# Getting ceaseless-edge metadata
# Error list index out of range id: 845
# Getting bleakwind-storm metadata
# Error list index out of range id: 846
# Getting wildbolt-storm metadata
# Error list index out of range id: 847
# Getting sandsear-storm metadata
# Error list index out of range id: 848
# Getting lunar-blessing metadata
# Error list index out of range id: 849
# Getting take-heart metadata
# Error list index out of range id: 850
# Getting tera-blast metadata
# Error list index out of range id: 851
# Getting silk-trap metadata
# Error list index out of range id: 852
# Getting axe-kick metadata
# Error list index out of range id: 853
# Getting last-respects metadata
# Error list index out of range id: 854
# Getting lumina-crash metadata
# Error list index out of range id: 855
# Getting order-up metadata
# Error list index out of range id: 856
# Getting jet-punch metadata
# Error list index out of range id: 857
# Getting spicy-extract metadata
# Error list index out of range id: 858
# Getting spin-out metadata
# Error list index out of range id: 859
# Getting population-bomb metadata
# Error list index out of range id: 860
# Getting ice-spinner metadata
# Error list index out of range id: 861
# Getting glaive-rush metadata
# Error list index out of range id: 862
# Getting revival-blessing metadata
# Error list index out of range id: 863
# Getting salt-cure metadata
# Error list index out of range id: 864
# Getting triple-dive metadata
# Error list index out of range id: 865
# Getting mortal-spin metadata
# Error list index out of range id: 866
# Getting doodle metadata
# Error list index out of range id: 867
# Getting fillet-away metadata
# Error list index out of range id: 868
# Getting kowtow-cleave metadata
# Error list index out of range id: 869
# Getting flower-trick metadata
# Error list index out of range id: 870
# Getting torch-song metadata
# Error list index out of range id: 871
# Getting aqua-step metadata
# Error list index out of range id: 872
# Getting raging-bull metadata
# Error list index out of range id: 873
# Getting make-it-rain metadata
# Error list index out of range id: 874
# Getting psyblade metadata
# Error list index out of range id: 875
# Getting hydro-steam metadata
# Error list index out of range id: 876
# Getting ruination metadata
# Error list index out of range id: 877
# Getting collision-course metadata
# Error list index out of range id: 878
# Getting electro-drift metadata
# Error list index out of range id: 879
# Getting shed-tail metadata
# Error list index out of range id: 880
# Getting chilly-reception metadata
# Error list index out of range id: 881
# Getting tidy-up metadata
# Error list index out of range id: 882
# Getting snowscape metadata
# Error list index out of range id: 883
# Getting pounce metadata
# Error list index out of range id: 884
# Getting trailblaze metadata
# Error list index out of range id: 885
# Getting chilling-water metadata
# Error list index out of range id: 886
# Getting hyper-drill metadata
# Error list index out of range id: 887
# Getting twin-beam metadata
# Error list index out of range id: 888
# Getting rage-fist metadata
# Error list index out of range id: 889
# Getting armor-cannon metadata
# Error list index out of range id: 890
# Getting bitter-blade metadata
# Error list index out of range id: 891
# Getting double-shock metadata
# Error list index out of range id: 892
# Getting gigaton-hammer metadata
# Error list index out of range id: 893
# Getting comeuppance metadata
# Error list index out of range id: 894
# Getting aqua-cutter metadata
# Error list index out of range id: 895
# Getting blazing-torque metadata
# Error list index out of range id: 896
# Getting wicked-torque metadata
# Error list index out of range id: 897
# Getting noxious-torque metadata
# Error list index out of range id: 898
# Getting combat-torque metadata
# Error list index out of range id: 899
# Getting magical-torque metadata
# Error list index out of range id: 900
# Getting blood-moon metadata
# Error list index out of range id: 901
# Getting matcha-gotcha metadata
# Error list index out of range id: 902
# Getting syrup-bomb metadata
# Error list index out of range id: 903
# Getting ivy-cudgel metadata
# Error list index out of range id: 904
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/905/ id: 905
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/906/ id: 906
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/907/ id: 907
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/908/ id: 908
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/909/ id: 909
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/910/ id: 910
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/911/ id: 911
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/912/ id: 912
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/913/ id: 913
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/914/ id: 914
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/915/ id: 915
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/916/ id: 916
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/917/ id: 917
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/918/ id: 918
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/919/ id: 919
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/920/ id: 920
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/921/ id: 921
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/922/ id: 922
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/923/ id: 923
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/924/ id: 924
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/925/ id: 925
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/926/ id: 926
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/927/ id: 927
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/928/ id: 928
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/929/ id: 929
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/930/ id: 930
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/931/ id: 931
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/932/ id: 932
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/933/ id: 933
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/934/ id: 934
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/935/ id: 935
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/936/ id: 936
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/937/ id: 937
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/938/ id: 938
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/939/ id: 939
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/940/ id: 940
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/941/ id: 941
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/942/ id: 942
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/943/ id: 943
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/944/ id: 944
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/945/ id: 945
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/946/ id: 946
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/947/ id: 947
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/948/ id: 948
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/949/ id: 949
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/950/ id: 950
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/951/ id: 951
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/952/ id: 952
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/953/ id: 953
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/954/ id: 954
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/955/ id: 955
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/956/ id: 956
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/957/ id: 957
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/958/ id: 958
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/959/ id: 959
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/960/ id: 960
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/961/ id: 961
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/962/ id: 962
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/963/ id: 963
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/964/ id: 964
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/965/ id: 965
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/966/ id: 966
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/967/ id: 967
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/968/ id: 968
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/969/ id: 969
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/970/ id: 970
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/971/ id: 971
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/972/ id: 972
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/973/ id: 973
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/974/ id: 974
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/975/ id: 975
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/976/ id: 976
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/977/ id: 977
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/978/ id: 978
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/979/ id: 979
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/980/ id: 980
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/981/ id: 981
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/982/ id: 982
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/983/ id: 983
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/984/ id: 984
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/985/ id: 985
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/986/ id: 986
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/987/ id: 987
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/988/ id: 988
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/989/ id: 989
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/990/ id: 990
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/991/ id: 991
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/992/ id: 992
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/993/ id: 993
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/994/ id: 994
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/995/ id: 995
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/996/ id: 996
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/997/ id: 997
# Error 404 Client Error: Not Found for url: https://pokeapi.co/api/v2/move/998/ id: 998
#           name  id  accuracy  pp  power  priority      type    generation  \
# 0        pound   1     100.0  35   40.0         0    normal  generation-i
# 1  karate-chop   2     100.0  25   50.0         0  fighting  generation-i
# 2  double-slap   3      85.0  10   15.0         0    normal  generation-i
# 3  comet-punch   4      85.0  15   18.0         0    normal  generation-i
# 4   mega-punch   5      85.0  20   80.0         0    normal  generation-i
#
#                                     short_descripton damage_class
# 0  Inflicts regular damage with no additional eff...     physical
# 1        Has an increased chance for a critical hit.     physical
# 2                        Hits 2-5 times in one turn.     physical
# 3                        Hits 2-5 times in one turn.     physical
# 4  Inflicts regular damage with no additional eff...     physical

# %% [markdown]
# ### Cleaning pokemon dataframe

# %%
# capitalizing the names of pokemons
poke_df['name'] = poke_df['name'].str.title()

# separation the types and capitalize the types
list_types = poke_df['types']
poke_df['type_1'] = poke_df['types'].apply(lambda x: x[0] if len(x) > 0 else None).str.title()
poke_df['type_2'] = poke_df['types'].apply(lambda x: x[1] if len(x) > 1 else None).str.title()

# getting th abilities colunms
df_pokemon_abilities = poke_df['abilities']

# droping the columns
df_pokemon_clean = poke_df.drop('types', axis=1)
df_pokemon_clean = df_pokemon_clean.drop('abilities', axis=1)

# chaging the types of datas in the columns
df_pokemon_clean['type_1'] = df_pokemon_clean['type_1'].astype('category')
df_pokemon_clean['type_2'] = df_pokemon_clean['type_2'].astype('category')

# %% [markdown]
# ### Cleaning moves dataframe

# %%
# cleaning name column
moves_data['name'] = moves_data['name'].str.replace('-', ' ')
moves_data['generation'] = moves_data['generation'].str.replace('-', ' ')
moves_data['generation'] = moves_data['generation'].str.title()
moves_data['type'] = moves_data['type'].str.title()
moves_data['damage_class'] = moves_data['damage_class'].str.title()

moves_data.describe()
# Out:
#                id    accuracy          pp       power    priority
# count  808.000000  541.000000  808.000000  486.000000  808.000000
# mean   405.570545   95.212569   13.873762   79.158436    0.023515
# std    235.160369   10.055453    8.651674   40.762546    0.858339
# min      1.000000   30.000000    1.000000   10.000000   -7.000000
# 25%    202.750000   90.000000   10.000000   55.000000    0.000000
# 50%    404.500000  100.000000   10.000000   80.000000    0.000000
# 75%    606.250000  100.000000   20.000000  100.000000    0.000000
# max    826.000000  100.000000   40.000000  250.000000    5.000000

# %%
# expoting the moves metadata
moves_data.to_csv('metadata_pokemon_moves.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Thiago\Desktop\data_camp_notebooks\data_science\projects\data_visualization_pokemon\notebook-poke4.ipynb Cell 14 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Thiago/Desktop/data_camp_notebooks/data_science/projects/data_visualization_pokemon/notebook-poke4.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> # expoting the moves metadata
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Thiago/Desktop/data_camp_notebooks/data_science/projects/data_visualization_pokemon/notebook-poke4.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a> moves_data.to_csv('metadata_pokemon_moves.csv', index=False)
#
# NameError: name 'moves_data' is not defined

# %%
# exporting the pokemon metadata
df_pokemon_clean.to_csv('metadata_pokemon.csv', index=False)
